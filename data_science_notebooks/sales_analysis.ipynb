# %%
# Import libs

# Libs for modeling
import numpy as np
import pandas as pd

# Libs for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Lib to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read data
data = pd.read_csv('PS4_GamesSales.csv', encoding='latin-1')

data.shape
# Out:
# (1034, 9)

# %%
# Head

data.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
# Nulls

data.isnull().sum()
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
plt.figure( figsize=(12,6))
plt.title('Null Analysis')
sns.heatmap( data.isnull(), cbar=False );

# %%
data.dropna( inplace = True )

# %%
# Describre

data.describe()
# Out:
#               Year  North America      Europe       Japan  Rest of World  \
# count   825.000000     825.000000  825.000000  825.000000     825.000000
# mean   2015.966061       0.256448    0.311600    0.042048       0.111552
# std       1.298360       0.620259    0.868271    0.119814       0.274713
# min    2013.000000       0.000000    0.000000    0.000000       0.000000
# 25%    2015.000000       0.000000    0.000000    0.000000       0.000000
# 50%    2016.000000       0.050000    0.020000    0.000000       0.020000
# 75%    2017.000000       0.190000    0.220000    0.040000       0.090000
# max    2020.000000       6.180000    9.710000    2.170000       3.020000
#
#            Global
# count  825.000000
# mean     0.721721
# std      1.743122
# min      0.000000
# 25%      0.030000
# 50%      0.120000
# 75%      0.560000
# max     19.390000

# %%
plt.figure( figsize=(12,6))

sns.barplot( data=data, x='Year', y='Global', ci=None, color='lightgreen',estimator=sum)

plt.title('Global sales volume (mi)', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# %%
data = data.loc[ (data['Year'] != 2019) & (data['Year'] != 2020)];

# %%
plt.figure( figsize=(12,6))

sns.barplot( data=data, x='Year', y='Global', ci=None, color='lightgreen',estimator=sum)

plt.title('Global sales volume (mi)', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# %%
plt.figure( figsize=(12,6))

plt.style.use('ggplot')

plt.title('Global sales distribution', loc='left', fontsize=14)

sns.kdeplot( data=data['Global'], shade=True, color='lightgreen', linewidth=2.5);

# %%
data.groupby( by=['Year']).sum()
# Out:
#         North America  Europe  Japan  Rest of World  Global
# Year
# 2013.0          10.35   12.88   0.97           4.57   28.76
# 2014.0          39.80   54.12   3.58          18.29  115.85
# 2015.0          49.60   56.21   7.28          20.88  133.99
# 2016.0          47.40   57.98   9.65          20.71  135.72
# 2017.0          44.77   57.18   9.08          19.89  130.90
# 2018.0          19.65   18.70   4.13           7.69   50.20

# %%
plt.figure( figsize=(12,6))

sns.boxplot( data=data, x='Year', y='Global', color='lightgreen')

plt.title('Global sales distribution', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# %%
data.loc[ data['Global'] >= 10]
# Out:
#                         Game    Year             Genre  \
# 0         Grand Theft Auto V  2014.0            Action
# 1  Call of Duty: Black Ops 3  2015.0           Shooter
# 2      Red Dead Redemption 2  2018.0  Action-Adventure
# 3         Call of Duty: WWII  2017.0           Shooter
# 4                    FIFA 18  2017.0            Sports
# 5                    FIFA 17  2016.0            Sports
# 6            Uncharted (PS4)  2016.0            Action
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# 3                      Activision           4.67    6.21   0.40
# 4                       EA Sports           1.27    8.64   0.15
# 5                 Electronic Arts           1.26    7.95   0.12
# 6  Sony Interactive Entertainment           4.49    3.93   0.21
#
#    Rest of World  Global
# 0           3.02   19.39
# 1           2.44   15.09
# 2           2.26   13.94
# 3           2.12   13.40
# 4           1.73   11.80
# 5           1.61   10.94
# 6           1.70   10.33

# %%
Analise = data.groupby( by=['Year'] ).sum().reset_index()

America = [ America / Total * 100 for America, Total in zip( Analise['North America'], Analise['Global'] ) ]
Europa = [ Europa / Total * 100 for Europa, Total in zip( Analise['Europe'], Analise['Global'] ) ]
Japan = [ Japao / Total * 100 for Japao, Total in zip( Analise['Japan'], Analise['Global'] ) ]
World = [ Mundo / Total * 100 for Mundo, Total in zip( Analise['Rest of World'], Analise['Global'] ) ]

# %%
plt.figure( figsize=(12,6))

bar_length = 0.8
labels = Analise['Year']
groups = [0,1,2,3,4,5]

plt.bar(groups,America,width = bar_length, color='lightgreen', edgecolor='white')

plt.bar(groups,Europa, bottom=America, width = bar_length, color='lightblue', edgecolor='white')

plt.bar(groups,Japan, bottom=[ A + B for A,B in zip(America,Europa)], width = bar_length, color='pink', edgecolor='white')

plt.bar(groups,World, bottom=[ A + B +C for A,B,C in zip(America,Europa,Japan)], width = bar_length, color='purple', edgecolor='white')

plt.title('Sales distribution per region', loc='left', fontsize=14)
plt.ylabel('Percentage (%)')

plt.xticks( groups,labels)
plt.xlabel('Group');

plt.legend(['America N','Europa', 'Japan', 'World'], loc='upper left', bbox_to_anchor=(0.23,-0.1), ncol=4)

# %%
data['Publisher'].unique()
# Out:
# array(['Rockstar Games', 'Activision', 'EA Sports', 'Electronic Arts',
#        'Sony Interactive Entertainment', 'Bethesda Softworks',
#        'Sony Computer Entertainment', 'Namco Bandai Games', 'Square Enix',
#        'Capcom', 'Blizzard Entertainment', 'Ubisoft',
#        'Warner Bros. Interactive', '2K Sports',
#        'Warner Bros. Interactive Entertainment',
#        'Konami Digital Entertainment', '2K Games', 'Hello Games',
#        '505 Games', 'Deep Silver', 'Take-Two Interactive',
#        'Bandai Namco Games', 'Sega', 'Tecmo Koei', 'Gearbox Software',
#        'Mojang', 'Disney Interactive Studios', 'Focus Home Interactive',
#        'Studio Wildcard', 'Codemasters', 'Koch Media',
#        'Harmonix Music Systems', 'Rebellion Developments', 'Gun Media',
#        'Telltale Games', 'Kalypso Media', 'City Interactive',
#        'NIS America', 'Sold Out', 'Tripwire Interactive', 'PQube',
#        'THQ Nordic', 'Milestone S.r.l.', 'Nordic Games', 'Astragon',
#        'Koei Tecmo', 'Frontier Developments', 'Marvelous Interactive',
#        'Arc System Works', 'Milestone', 'Milestone S.r.l', 'System 3',
#        'Paradox InteractiveÊ', 'Dusenberry Martin Racing',
#        'Insomniac Games', 'Idea Factory International',
#        'Yacht Club Games', 'Little Orbit', 'Ravenscourt', 'Maximum Games',
#        'Acquire', 'Bigben Interactive', 'Atlus',
#        'Nihon Falcom Corporation', 'Tru Blu Entertainment', 'GameTrust',
#        'Grey Box', 'D3Publisher', 'Devolver Digital', 'Gaijinworks',
#        'Funbox Media', 'Microids', 'Xseed Games', 'Badland Studio',
#        'GameMill', 'Nippon Ichi Software', 'Aksys Games',
#        'Revolution Software', 'Games Workshop', 'Atari', 'Nicalis',
#        'Ready at Dawn', 'Big Ben Interactive', 'Accolade', 'Soedesco',
#        'Team17 Digital Ltd', 'Introversion Software', 'Rising Star Games',
#        'Outright Games', 'Alternative Software', 'Nighthawk Interactive',
#        'Compile Heart', 'MLB.com', 'Techland', 'Avanquest', 'Merge Games',
#        'CokeM Interactive', '5pb', 'Perp Games', 'UFO Interactive',
#        'Wired Productions', 'Kadokawa Games', 'Yeti', 'Sprite',
#        'PM Studios', 'Gunho Online Entertainment',
#        'GameMill Entertainment', 'Stainless Games', 'League of Geeks',
#        'Mediascape', 'Rebellion', 'GungHo', 'TopWare Interactive', 'M2',
#        'UIG Entertainment', 'Active Gaming Media', 'Rain Games',
#        'Team17 Software', 'Team Meat', 'Thekla, Inc.', 'Entergram',
#        'DMM Games', 'Two Tribes', 'Spike Chunsoft',
#        'Perfect World Entertainment', 'BioWare',
#        'Sony Online Entertainment', 'Unknown', 'Taleworlds',
#        'DTP Entertainment', 'CD Projekt Red Studio', 'Compulsion Games',
#        'FarSight Studios', 'Futurlab 1', 'Level 5', 'Nowhere Studios',
#        'Frictional Games', 'Renegade Kid', 'Triniti Interactive',
#        '3D Realms', 'Endnight Games LtdÊ', 'Versus Evil',
#        'The Astronauts', 'Ice-pick Lodge', 'Double Damage Games',
#        'Wander MMO', 'Sinxsoft', 'Daedalic Entertainment',
#        'Bandai Namco Entertainment', 'Tammeka Games'], dtype=object)

# %%
sns.boxplot( data=data, x='Publisher',y='Global')

# %%
from sklearn.preprocessing import LabelEncoder
funcao_label = LabelEncoder()

data['Publisher*'] = funcao_label.fit_transform(data['Publisher'])
data['Genre*'] = funcao_label.fit_transform(data['Genre'])
data['Game*'] = funcao_label.fit_transform(data['Game'])

data.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global  Publisher*  Genre*  \
# 0           6.06    9.71   0.60           3.02   19.39         107       0
# 1           6.18    6.05   0.41           2.44   15.09           8      12
# 2           5.26    6.21   0.21           2.26   13.94         107       1
# 3           4.67    6.21   0.40           2.12   13.40           8      12
# 4           1.27    8.64   0.15           1.73   11.80          40      14
#
#    Game*
# 0    273
# 1     98
# 2    521
# 3    102
# 4    222

# %%
color_palette = sns.color_palette('Greens_r',4)
color_palette
# Out:
# [(0.08235294117647059, 0.49803921568627446, 0.23137254901960783),
#  (0.29490196078431374, 0.6901960784313725, 0.38431372549019605),
#  (0.596078431372549, 0.8345098039215686, 0.5788235294117647),
#  (0.8274509803921569, 0.9325490196078431, 0.8031372549019608)]

# %%
plt.figure( figsize=(12,6))

sns.scatterplot(data=data, x='Publisher*', y='Global', color=color_palette[0])

plt.title('Global sales per publisher', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# %%
plt.figure( figsize=(12,6))

sns.scatterplot(data=data, x='Genre*', y='Global', color=color_palette[0])

plt.title('Global sales per genre', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# %%
plt.figure( figsize=(12,6))

sns.scatterplot(data=data, x='Game*', y='Global', color=color_palette[0])

plt.title('Global sales per game', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# %%
# Report

# Report size
fig, ax = plt.subplots( figsize=(18,15) )

# Backgtound Color
color = 'lightgrey'
ax.set_facecolor(color)
fig.set_facecolor(color)

# Subplot style
plt.style.use('seaborn')

# Report title
plt.suptitle("Python for Data Science \n Videogames' global sales analysis",
             fontsize=22, color='grey', fontweight=600 )

# Parameters
linhas = 3
colunas = 2

# Subplot 1
plt.subplot( linhas, colunas, 1)
plt.bar( data['Year'], data['Global'], color=color_palette[1])
plt.title('Global sales volume (mi)', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# Subplot 2
plt.subplot( linhas, colunas, 2)
sns.boxplot( data=data, x='Year', y='Global', color=color_palette[1])
plt.title('Global sales distribution', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# Subplot 3
plt.subplot( linhas, colunas, 3)
bar_length = 0.8
labels = Analise['Year']
groups = [0,1,2,3,4,5]
plt.bar(groups,America,width = bar_length, color=color_palette[0], edgecolor='white')
plt.bar(groups,Europa, bottom=America, width = bar_length, color=color_palette[1], edgecolor='white')
plt.bar(groups,Japan, bottom=[ A + B for A,B in zip(America,Europa)], width = bar_length, color=color_palette[2], edgecolor='white')
plt.bar(groups,World, bottom=[ A + B +C for A,B,C in zip(America,Europa,Japan)], width = bar_length, color=color_palette[3], edgecolor='white')
plt.title('Sales distribution per region', loc='left', fontsize=14)
plt.ylabel('Percentage (%)')
plt.xticks( groups,labels)
plt.xlabel('Group');
plt.legend(['America N','Europa', 'Japan', 'World'], loc='upper left', bbox_to_anchor=(0.23,-0.1), ncol=4)

# Subplot 4
plt.subplot( linhas, colunas, 4)
sns.scatterplot(data=data, x='Publisher*', y='Global', color=color_palette[1])
plt.title('Global sales per publisher', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# Subplot 5
plt.subplot( linhas, colunas, 5)

sns.scatterplot(data=data, x='Genre*', y='Global', color=color_palette[1])
plt.title('Global sales per genre', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# Subplot 6
plt.subplot( linhas, colunas, 6)
sns.scatterplot(data=data, x='Game*', y='Global', color=color_palette[1])
plt.title('Global sales per game', loc='left', fontsize=14)
plt.ylabel('Global sales (mi)');

# Layout
plt.subplots_adjust( hspace=0.3, wspace=0.15)

# Footnote
footnote = '''
This report was made as a training pratice for "Python para Análise de Dados" online course, available at Udemy.
'''

fig.text(0.5, -0.002, footnote, ha='center', va='bottom', size=12, color='grey')
# Out:
# Text(0.5, -0.002, '\nThis report was made as a training pratice for "Python para Análise de Dados" online course, available at Udemy.\n')
