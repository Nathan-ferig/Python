# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df = px.data.gapminder().query('country == "Brazil"').set_index('year')

# %%
df.head()
# Out:
#      country continent  lifeExp        pop    gdpPercap iso_alpha  iso_num
# year
# 1952  Brazil  Americas   50.917   56602560  2108.944355       BRA       76
# 1957  Brazil  Americas   53.285   65551171  2487.365989       BRA       76
# 1962  Brazil  Americas   55.665   76039390  3336.585802       BRA       76
# 1967  Brazil  Americas   57.632   88049823  3429.864357       BRA       76
# 1972  Brazil  Americas   59.504  100840058  4985.711467       BRA       76

# %%
plt.plot(df.index, df['gdpPercap'])
plt.title("Brazil's GDP per Capita")
plt.ylabel("GDP per capita")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
title = "Life expectancy versus GDP per Capita in Brazil"

plt.figure(figsize = (12,4))
plt.plot(df['lifeExp'], df['gdpPercap'], '--bo')
plt.title(title, loc = 'left')
plt.ylabel("GDP per capita'")
plt.xlabel("Life Expectancy")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(x = df.index,
       height = df['pop'],
       color = 'red'
       )
plt.title("Brazil's Population Growth")
# Out:
# Text(0.5, 1.0, "Brazil's Population Growth")

# %%
def filter_continent(continent):
    df = px.data.gapminder()
    df = df[df['continent'] == continent]
    return df

# %%
def filter_country(country,variable):
    df = px.data.gapminder()
    df = df[df['country'] == country][variable]
    return df

# %%
continent_name = 'Americas'
continent = filter_continent(continent_name)
countries = continent['country'].unique()
plt.figure(figsize = (12,8))
for country in countries:
    plt.scatter(filter_country(country = country,
                             variable = 'lifeExp'
                            ),
                filter_country(country = country,
                            variable = 'gdpPercap'
                            )
            )
title = 'Life expectancy versus GDP per Capita in ' + continent_name
plt.title(title, loc = 'left')
plt.legend(labels = countries, loc = 'best')
plt.ylabel("GDP per capita'")
plt.xlabel("Life Expectancy")
# Out:
# Text(0.5, 0, 'Life Expectancy')
